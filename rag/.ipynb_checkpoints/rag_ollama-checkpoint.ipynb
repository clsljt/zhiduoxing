# %%
# from langchain_chroma import Chroma
from langchain.vectorstores import Chroma
from langchain_ollama import OllamaEmbeddings
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_ollama import ChatOllama
from langchain_core.runnables import RunnablePassthrough
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
# local_embeddings = OllamaEmbeddings(model="/root/autodl-tmp/ollama_model")
embeddings = HuggingFaceEmbeddings(model_name='/root/autodl-tmp/m3e-base',
                                      model_kwargs={'device': 'cuda'})

vectorstore = Chroma(persist_directory="./chroma_db/test_02", embedding_function=embeddings)
# vectorstore = Chroma("/root/rag/chroma_db/test_01", embedding=local_embeddings)
# Out:
# No sentence-transformers model found with name /root/autodl-tmp/m3e-base. Creating a new one with mean pooling.
# /tmp/ipykernel_47185/3353937728.py:5: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vectorstore = Chroma(persist_directory="./chroma_db/test_02", embedding_function=embeddings)

# %%
question = ""
docs = vectorstore.similarity_search(question)
len(docs)
# Out:
# 4

# %%
model = ChatOllama(
    model="qwen2.5:32b",
)

# %%
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %%
RAG_TEMPLATE = """
You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.

<context>
{context}
</context>

Answer the following question:

{question}"""

rag_prompt = ChatPromptTemplate.from_template(RAG_TEMPLATE)

chain = (
    RunnablePassthrough.assign(context=lambda input: format_docs(input["context"]))
    | rag_prompt
    | model
    | StrOutputParser()
)

# %%
question = "科技成果转化现金奖励需要提交期限"

docs = vectorstore.similarity_search(question)

# print(docs)
# Run
chain.invoke({"context": docs, "question": question})
# Out:
# '扣缴义务人应于向科技人员实际发放现金奖励之日的次月15日内报送。'

# %%
model.invoke(question).content
# Out:
# '科技成果转化所涉及的现金奖励，通常是为了激励科研人员将科技成果有效地转化为实际应用与经济价值。不同地区、不同的机构可能有不同的具体要求和流程，但一般来说，申请此类现金奖励时需要准备以下几类基础性文件：\n\n1. **项目合同或协议**：证明该科技成果转化项目的存在以及相关方的权利义务关系。\n\n2. **科技成果鉴定书/评价报告**：通常由专业的第三方评估机构出具，用以确认科技成果的创新性和实用性价值。\n\n3. **转化实施材料**：包括但不限于技术转移协议、专利证书（如适用）、产品样品或服务证明等，展示科技成果已进入市场应用阶段的相关文件。\n\n4. **财务报表及收入证明**：反映科技成果转化带来的经济效益，可能需要提供项目收支明细表、纳税证明等。\n\n5. **奖励分配方案**：明确现金奖励的计算方法和具体分配到个人的比例或数额。这应当符合相关法律法规的要求，并确保公平合理。\n\n6. **申请表格及其他辅助材料**：根据所在单位或政府部门的具体要求填写相关的申请表格，同时提供能够支持上述各类信息真实性的其他补充材料。\n\n请注意，以上仅为一般性指导建议，在实际操作过程中应以当地政策规定和组织内部规章制度为准。如果有疑问，最好直接咨询项目所属机构的科研管理部门或者财务部门获取最准确的信息。'

# %%
# Test Server

# %%
import requests
import json

def get_completion(prompt):
    headers = {'Content-Type': 'application/json'}
    data = {"prompt": prompt}
    response = requests.post(url='http://127.0.0.1:1024', headers=headers, data=json.dumps(data))
    # print(response)
    return response.json()

if __name__ == '__main__':
    print(get_completion('培训费有多少'))
# Out:
# 根据北京信息科技大学财务报销手册（2024版），培训费的标准是每人每天550元，其中包括住宿费340元、伙食费130元、场地费和资料费等50元以及其他费用30元。各项费用之间可以调剂使用。
