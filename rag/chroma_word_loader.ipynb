# %%
from langchain.vectorstores import Chroma
from langchain.document_loaders import TextLoader
from langchain.embeddings import HuggingFaceEmbeddings
from langchain_community.document_loaders import UnstructuredWordDocumentLoader

# %% [markdown]
# ## dir

# %%
import os

# %%
dir_word = "/root/rag/rag_data/dataDOC/"
word_lis = os.listdir(dir_word)

# %%
word_lis
# Out:
# ['复翼发票助手小程序使用指南.docx',
#  '科技成果转化现金奖励备案表填报说明.docx',
#  '商学院关于开展2023-2024学年本科生国家奖学金评审与材料填报工作的通知.doc',
#  '关于开展2024年学生公派出国学习奖学金评审的通知.docx',
#  '附件6：北京信息科技大学2024年国家励志奖学金名额分配表.doc']

# %%
for i in word_lis:
    try:
        loader = Docx2txtLoader(dir_word+i)
        data = loader.load()
    except:
        print(i)
# Out:
# 商学院关于开展2023-2024学年本科生国家奖学金评审与材料填报工作的通知.doc
# 附件6：北京信息科技大学2024年国家励志奖学金名额分配表.doc

# %% [markdown]
# ## word

# %%
loader = Docx2txtLoader("/root/rag/rag_data/dataDOC/复翼发票助手小程序使用指南.docx")
data = loader.load()

# %%
embeddings = HuggingFaceEmbeddings(model_name='/root/autodl-tmp/m3e-base',
                                      model_kwargs={'device': 'cuda'})

vectorstore = Chroma(persist_directory="./chroma_db/test_01", embedding_function=embeddings)
# Out:
# /tmp/ipykernel_43717/2188971312.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name='/root/autodl-tmp/m3e-base',
# No sentence-transformers model found with name /root/autodl-tmp/m3e-base. Creating a new one with mean pooling.
# /tmp/ipykernel_43717/2188971312.py:4: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
# ...

# %% [markdown]
# ## Excel

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# import pandas as pd
from langchain_community.document_loaders import UnstructuredExcelLoader

loader = UnstructuredExcelLoader("/root/rag/rag_data/dataEXCEL/校院两级二级分配表-2022年版本.xls", mode="elements")
docs = loader.load()

# %%
docs
# Out:
# [Document(metadata={'source': '/root/rag/rag_data/dataEXCEL/校院两级二级分配表-2022年版本.xls', 'file_directory': '/root/rag/rag_data/dataEXCEL', 'filename': '校院两级二级分配表-2022年版本.xls', 'last_modified': '2025-04-21T14:31:13', 'page_name': 'Sheet2', 'page_number': 1, 'languages': ['zho'], 'filetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'category': 'Title', 'element_id': '54c223675bb47495ac176bea2515bd6a'}, page_content='年度校院两级运行维持经费二次分配表---单位（万元）'),
# ...

# %% [markdown]
# ## update

# %%
vectorstore.add_documents(documents=data)
# Out:
# ['b83dc800-5fce-47ee-8e65-96f9126c84f6']
